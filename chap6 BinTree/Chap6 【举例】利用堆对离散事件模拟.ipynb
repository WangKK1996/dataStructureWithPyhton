# %%
from random import randint

# %% [markdown]
# 在做模拟之前，我们需要之前定义的两个类：SQueue和prioQueue

# %% [markdown]
# ### SQueue的定义

# %%
# 队列类的实现
class SQueue():
    def __init__(self, init_len = 8):
        self._len = init_len # 存储区长度
        self._elems = [0] * init_len # 元素存储
        self._head = 0 # 表头元素下标
        self._num = 0 # 元素个数
    
    def is_empty(self):
        return self._num == 0

    def peek(self):
        if self._num == 0:
            raise QueueUnderflow
        return self._elems[self._head]
    
    def dequeue(self):
        if self._num == 0:
            raise QueueUnderflow
        e = self._elems[self._head]
        self._head = (self._head + 1)%self._len
        self._num -= 1
        return e
    
    def enqueue(self, e):
        if self._num == self._len:
            self.__extend()
        self._elems[(self._head + self._num) % self._len] = e
        self._num += 1
        
    def __extend(self):
        old_len = self._len
        self._len *= 2
        new_elems = [0]*self._len
        for i in range(old_len):
            new_elems[i] = self._elems[(self._head + i) % old_len]
            self._elems, self._head = new_elems, 0

# %%
a = SQueue()
a.enqueue(3)
a.enqueue(5)
a.dequeue()
a.peek()
# Out:
# 5

# %% [markdown]
# ### prioQueue的定义

# %%
class PrioQueue:
    """
    利用堆来实现优先队列
    """
    def __init__(self, elist = []):
        self._elems = list(elist) # 这一步是使内部的表脱离原来的表，防止元素的共享
        if elist:
            self.buildheap()
    
    def is_empty(self):
        return not self._elems
    
    def peek(self):
        if self.is_empty():
            raise PrioQueueError("in peek")
        return self._elems[0]
    
    # 入队操作
    def enqueue(self, e):
        self._elems.append(None) # add a dummy elemnt
        self.siftup(e, len(self._elems)-1)
        
    def siftup(self, e, last):
        # 初始化，(元素-1//2)对应的是其根节点
        elems, i, j = self._elems, last, (last-1)//2 
        # 判断，当e小于其根节点的时候，把根节点一段一段往下移动
        while i > 0 and e < elems[j]:
            elems[i] = elems[j]
            i, j = j, (j-1)//2
        elems[i] = e
    
    # 弹出操作
    def dequeue(self):
        if self.is_empty():
            raise PrioQueueError("in queue")
        elems = self._elems
        e0 = elems[0]
        e = elems.pop()
        if len(elems) > 0:
            self.siftdown(e, 0, len(elems))
        return e0
    
    def siftdown(self, e, begin, end):
        # 初始化，begin*2+1找的是其左根结点
        elems, i, j = self._elems, begin, begin * 2 + 1
        while j < end:
            # 判断右结点（兄弟结点）的情况
            if j+1 < end and elems[j+1] < elems[j]:
                j += 1 # 保证elems[j]里的数据不大于其兄弟结点的数据
            # 这样就保证了根节点一定会小于兄弟结点中较小的那个
            if e < elems[j]: 
                break # 因为e已经在三者中最小，找到了位置
            elems[i] = elems[j] # 因为元素j在三者中最小，所以将其上移。
            i, j = j, j * 2 + 1 # 更新i，j指针
        elems[i] = e
    
    # 堆的初始构建
    def buildheap(self):
        end = len(self._elems)
        # 从end//2开始做是因为，后面的元素已经是叶结点（顺序表转化为二叉树的特有性质）
        # 所以，它们中的每一个都已经是一个堆了；
        # 从完全二叉树的最下最右分支结点开始，往左建堆
        # 然后再到上一层建堆；
        # 最后，整个表成为一个堆
        # 这个工作实际上就是在两个已有的堆上加上一个根元素，使其成为堆
        for i in range(end//2, -1, -1):
            self.siftdown(self._elems[i], i, end)

# %% [markdown]
# Simulation是一个基础的模拟对象

# %%
class Simulation:
    def __init__(self, duration):
        self._eventq = PrioQueue() # 一个优先队列？
        self._time = 0
        self._duration = duration
        
    def run(self):
        while not self._eventq.is_empty(): # 模拟到事件队列空
            event = self._eventq.dequeue()
            self._time = event.time()
            if self._time > self._duration: # 同理，当时间用完时，也停止
                break
            event.run()
    
    def add_event(self, event):
        self._eventq.enqueue(event)
        
    def cur_time(self):
        return self._time

# %% [markdown]
# 接下来定义一个基础的事件类

# %%
class Event:
    def __init__(self, event_time, host):
        self._ctime = event_time
        self._host = host
    
    def __lt__(self, other_event):
        return self._ctime < other_event._ctime
    def __le__(self, other_event):
        return self._ctime <= other_event._ctime
    
    def host(self):
        return self._host
    
    def time(self):
        return self._ctime
    
    def run(self): # 具体事件类必须定义这个方法
        pass

# %% [markdown]
# ### 模拟类：Customs
# 接下来就是针对这些需求，提出正确的拟合方法
#
# 模拟的前提如下：
# * 车辆的速率具有一定的随机性，每a到b分钟有一辆车到达；
# * 海关有k条检查通道，每检查一条一辆车要耗费c到d分钟
# * 到达的车辆在一条专用线路上等待，一旦有一个检查通道空闲，正在等待的车辆就进入该通道检查（dequeue操作）
# * 如果车辆到达有空闲通道而且当时没有等待车辆，就立刻开始检查
#
# 目的：得到车辆的平均等待时间和通过检查站的平均时间

# %%
class Customs:
    def __init__(self, gate_num, duration,
                arrive_interval, check_interval):
        self.simulation = Simulation(duration)
        self.waitline = SQueue()
        self.duration = duration
        self.gates = [0] * gate_num
        self.total_wait_time = 0
        self.total_used_time = 0
        self.car_num = 0
        self.arrive_interval = arrive_interval
        self.check_interval = check_interval
        
    def wait_time_acc(self, n):
        self.total_wait_time += n
    
    def total_time_acc(self, n):
        self.total_used_time += n
    
    def car_count_1(self):
        self.car_num += 1
    
    def add_event(self, event):
        self.simulation.add_event(event)
    
    def cur_time(self):
        return self.simulation.cur_time()
    
    def enqueue(self, car):
        self.waitline.enqueue(car)
    
    def has_queued_car(self):
        return not self.waitline.is_empty()
    
    def next_car(self):
        return self.waitline.dequeue()
    
    def find_gate(self):
        for i in range(len(self.gates)):
            if self.gates[i] == 0:
                self.gates[i] = 1
                return i
        return None
    
    def free_gate(self, i):
        if self.gates[i] == 1:
            self.gates[i] = 0
        else:
            raise ValueError("Clear gate error.")
            
    # 最后的方法实施模拟和输出统计数据
    def simulate(self):
        Arrive(0, self) # 初始化，生成第一辆汽车
        self.simulation.run()
        self.statistics()
        
    def statistics(self):
        print("Simulate " + str(self.duration)
                + " minutes, for "
                + str(len(self.gates)) + "gates.")
        print(self.car_num, "cars pass the Customs")
        print("Average waiting time:",
             self.total_wait_time/self.car_num)
        print("Average passing time:",
             self.total_used_time/self.car_num)
        i = 0
        while not self.waitline.is_empty():
            self.waitline.dequeue()
            i += 1
        print(i, "cars are in waiting line.")

# %% [markdown]
# ### Car类
# 排队队列列的对象表示同行的车辆，类Car实现这种对象，对象中记录了一辆车的到达时间。

# %%
class Car:
    def __init__(self, arrive_time):
        self.time = arrive_time
    
    def arrive_time(self):
        return self.time

# %% [markdown]
# ### 事件类
# 海关检查的系统模拟需要以下几种事件：
# * **汽车到达事件** ， 一辆车到达生成一个Car事件，其中记录了它的到达时间；同时，这一事件的发生还意味着若干时间之后还有下一辆车要达到；故而定义一个类Arrive，规范此类事件的行为；
# * **汽车开始检查事件**
# * **汽车检查完毕后离开** ，定义类Leave

# %%
# 这个用来输出日志条目,在测试的时候就超级好用！
def event_log(time, name):
    print("Event: "+ name + ", happen at " + str(time))
    pass

# %%
# 首先是Arrive类
class Arrive(Event):
    def __init__(self, arrive_time, customs):
        Event.__init__(self, arrive_time, customs)
        customs.add_event(self)
        
    def run(self):
        time, customs = self.time(), self.host()
        event_log(time, "car arrive")
        # 生成下一个Arrive事件
        Arrive(time + randint(*customs.arrive_interval),
               customs)
        
        # 这一次到达车辆事件的行为
        car = Car(time)
        if customs.has_queued_car():
            customs.enqueue(car)
            return
        i = customs.find_gate() # 检查空闲通道
        if i is not None:
            event_log(time, "car check")
            Leave(time + randint(*customs.check_interval),
                 i, car, customs)
        else:
            customs.enqueue(car)

# %%
# 定义离开类
class Leave(Event):
    def __init__(self, leave_time, gate_num, car, customs):
        Event.__init__(self, leave_time, customs)
        self.car = car
        self.gate_num = gate_num
        customs.add_event(self)
        
    def run(self):
        time, customs = self.time(), self.host()
        event_log(time, "car leave")
        customs.free_gate(self.gate_num)
        customs.car_count_1()
        customs.total_time_acc(time - self.car.arrive_time())
        # 如果一辆车离开车站后，还有排队等待的车辆
        # 就检查其中第一辆车，并且生成相应的离开事件
        if customs.has_queued_car():
            car = customs.next_car()
            i = customs.find_gate()
            event_log(time,"car check")
            customs.wait_time_acc(time - car.arrive_time())
            Leave(time + randint(*customs.check_interval),
                 self.gate_num, car, customs)

# %% [markdown]
# ## 实际模拟
# 虽然上面那一通都是我抄书的，但是还是可以尝试一下模拟

# %%
car_arrive_interval = (1,2)
car_check_time = (4, 5)
cus = Customs(3, 480, car_arrive_interval, car_check_time)
cus.simulate()
# Out:
# Event: car arrive, happen at 0
# Event: car check, happen at 0
# Event: car arrive, happen at 1
# Event: car check, happen at 1
# Event: car arrive, happen at 2
# Event: car check, happen at 2
# Event: car leave, happen at 4
# Event: car arrive, happen at 4
# Event: car check, happen at 4
# Event: car leave, happen at 6
# Event: car leave, happen at 6
# Event: car arrive, happen at 6
# Event: car check, happen at 6
# Event: car arrive, happen at 7
# Event: car check, happen at 7
# Event: car leave, happen at 8
# Event: car arrive, happen at 9
# Event: car check, happen at 9
# Event: car arrive, happen at 10
# Event: car leave, happen at 11
# Event: car check, happen at 11
# Event: car arrive, happen at 11
# Event: car leave, happen at 12
# Event: car check, happen at 12
# Event: car arrive, happen at 12
# Event: car leave, happen at 13
# Event: car check, happen at 13
# Event: car arrive, happen at 14
# Event: car leave, happen at 16
# Event: car check, happen at 16
# Event: car arrive, happen at 16
# Event: car leave, happen at 16
# Event: car check, happen at 16
# Event: car leave, happen at 18
# Event: car arrive, happen at 18
# Event: car check, happen at 18
# Event: car arrive, happen at 19
# Event: car leave, happen at 21
# Event: car check, happen at 21
# Event: car arrive, happen at 21
# Event: car leave, happen at 21
# Event: car check, happen at 21
# Event: car leave, happen at 22
# Event: car arrive, happen at 22
# Event: car check, happen at 22
# Event: car arrive, happen at 23
# Event: car arrive, happen at 24
# Event: car arrive, happen at 25
# Event: car leave, happen at 26
# Event: car check, happen at 26
# Event: car arrive, happen at 26
# Event: car leave, happen at 26
# Event: car check, happen at 26
# Event: car leave, happen at 27
# Event: car check, happen at 27
# Event: car arrive, happen at 28
# Event: car arrive, happen at 29
# Event: car leave, happen at 30
# Event: car check, happen at 30
# Event: car arrive, happen at 30
# Event: car leave, happen at 31
# Event: car check, happen at 31
# Event: car leave, happen at 31
# Event: car check, happen at 31
# Event: car arrive, happen at 32
# Event: car arrive, happen at 33
# Event: car arrive, happen at 34
# Event: car leave, happen at 35
# Event: car check, happen at 35
# Event: car leave, happen at 35
# Event: car check, happen at 35
# Event: car leave, happen at 35
# Event: car check, happen at 35
# Event: car arrive, happen at 36
# Event: car arrive, happen at 38
# Event: car leave, happen at 39
# Event: car check, happen at 39
# Event: car arrive, happen at 39
# Event: car leave, happen at 40
# Event: car check, happen at 40
# Event: car leave, happen at 40
# Event: car check, happen at 40
# Event: car arrive, happen at 41
# Event: car arrive, happen at 42
# Event: car leave, happen at 43
# Event: car check, happen at 43
# Event: car arrive, happen at 44
# Event: car leave, happen at 45
# Event: car check, happen at 45
# Event: car leave, happen at 45
# Event: car check, happen at 45
# Event: car arrive, happen at 46
# Event: car leave, happen at 47
# Event: car check, happen at 47
# Event: car arrive, happen at 47
# Event: car leave, happen at 49
# Event: car check, happen at 49
# Event: car arrive, happen at 49
# Event: car leave, happen at 50
# Event: car check, happen at 50
# Event: car arrive, happen at 51
# Event: car leave, happen at 52
# Event: car check, happen at 52
# Event: car arrive, happen at 53
# Event: car leave, happen at 54
# Event: car check, happen at 54
# Event: car arrive, happen at 54
# Event: car leave, happen at 55
# Event: car check, happen at 55
# Event: car arrive, happen at 55
# Event: car leave, happen at 57
# Event: car check, happen at 57
# Event: car arrive, happen at 57
# Event: car leave, happen at 58
# Event: car check, happen at 58
# Event: car arrive, happen at 59
# Event: car leave, happen at 60
# Event: car check, happen at 60
# Event: car leave, happen at 61
# Event: car check, happen at 61
# Event: car arrive, happen at 61
# Event: car leave, happen at 63
# Event: car check, happen at 63
# Event: car arrive, happen at 63
# Event: car leave, happen at 64
# Event: car check, happen at 64
# Event: car arrive, happen at 65
# Event: car leave, happen at 65
# Event: car check, happen at 65
# Event: car arrive, happen at 66
# Event: car arrive, happen at 67
# Event: car leave, happen at 68
# Event: car check, happen at 68
# Event: car leave, happen at 68
# Event: car check, happen at 68
# Event: car arrive, happen at 69
# Event: car leave, happen at 70
# Event: car check, happen at 70
# Event: car arrive, happen at 70
# Event: car leave, happen at 72
# Event: car check, happen at 72
# Event: car arrive, happen at 72
# Event: car leave, happen at 72
# Event: car check, happen at 72
# Event: car leave, happen at 74
# Event: car arrive, happen at 74
# Event: car check, happen at 74
# Event: car arrive, happen at 75
# Event: car leave, happen at 76
# Event: car check, happen at 76
# Event: car leave, happen at 76
# Event: car arrive, happen at 77
# Event: car check, happen at 77
# Event: car leave, happen at 78
# Event: car arrive, happen at 79
# Event: car check, happen at 79
# Event: car arrive, happen at 80
# Event: car leave, happen at 81
# Event: car check, happen at 81
# Event: car leave, happen at 82
# Event: car arrive, happen at 82
# Event: car check, happen at 82
# Event: car arrive, happen at 83
# Event: car leave, happen at 84
# Event: car check, happen at 84
# Event: car arrive, happen at 84
# Event: car leave, happen at 86
# Event: car check, happen at 86
# Event: car arrive, happen at 86
# Event: car leave, happen at 86
# Event: car check, happen at 86
# Event: car arrive, happen at 87
# Event: car arrive, happen at 88
# Event: car leave, happen at 89
# Event: car check, happen at 89
# Event: car arrive, happen at 90
# Event: car leave, happen at 91
# Event: car check, happen at 91
# Event: car leave, happen at 91
# Event: car check, happen at 91
# Event: car arrive, happen at 92
# Event: car leave, happen at 93
# Event: car check, happen at 93
# Event: car arrive, happen at 94
# Event: car arrive, happen at 95
# Event: car leave, happen at 96
# Event: car check, happen at 96
# Event: car arrive, happen at 96
# Event: car leave, happen at 96
# Event: car check, happen at 96
# Event: car leave, happen at 97
# Event: car check, happen at 97
# Event: car arrive, happen at 98
# Event: car leave, happen at 100
# Event: car check, happen at 100
# Event: car arrive, happen at 100
# Event: car leave, happen at 101
# Event: car check, happen at 101
# Event: car arrive, happen at 101
# Event: car leave, happen at 102
# Event: car check, happen at 102
# Event: car arrive, happen at 102
# Event: car arrive, happen at 103
# Event: car leave, happen at 105
# Event: car check, happen at 105
# Event: car arrive, happen at 105
# Event: car leave, happen at 106
# Event: car check, happen at 106
# Event: car arrive, happen at 106
# Event: car leave, happen at 107
# Event: car check, happen at 107
# Event: car arrive, happen at 107
# Event: car leave, happen at 109
# Event: car check, happen at 109
# Event: car arrive, happen at 109
# Event: car leave, happen at 110
# Event: car check, happen at 110
# Event: car arrive, happen at 110
# Event: car leave, happen at 111
# Event: car check, happen at 111
# Event: car arrive, happen at 111
# Event: car arrive, happen at 112
# Event: car leave, happen at 114
# Event: car check, happen at 114
# Event: car arrive, happen at 114
# Event: car leave, happen at 114
# Event: car check, happen at 114
# Event: car leave, happen at 116
# Event: car check, happen at 116
# Event: car arrive, happen at 116
# Event: car arrive, happen at 117
# Event: car arrive, happen at 118
# Event: car leave, happen at 119
# Event: car check, happen at 119
# Event: car arrive, happen at 119
# Event: car leave, happen at 119
# Event: car check, happen at 119
# Event: car leave, happen at 121
# Event: car check, happen at 121
# Event: car arrive, happen at 121
# Event: car arrive, happen at 123
# Event: car leave, happen at 124
# Event: car check, happen at 124
# Event: car arrive, happen at 124
# Event: car leave, happen at 124
# Event: car check, happen at 124
# Event: car leave, happen at 125
# Event: car check, happen at 125
# Event: car arrive, happen at 126
# Event: car arrive, happen at 127
# Event: car leave, happen at 128
# Event: car check, happen at 128
# Event: car leave, happen at 129
# Event: car check, happen at 129
# Event: car arrive, happen at 129
# Event: car leave, happen at 130
# Event: car check, happen at 130
# Event: car arrive, happen at 131
# Event: car leave, happen at 132
# Event: car check, happen at 132
# Event: car arrive, happen at 132
# Event: car leave, happen at 133
# Event: car check, happen at 133
# Event: car arrive, happen at 133
# Event: car arrive, happen at 134
# Event: car leave, happen at 135
# Event: car check, happen at 135
# Event: car arrive, happen at 136
# Event: car leave, happen at 137
# Event: car check, happen at 137
# Event: car leave, happen at 138
# Event: car check, happen at 138
# Event: car arrive, happen at 138
# Event: car arrive, happen at 139
# Event: car leave, happen at 140
# Event: car check, happen at 140
# Event: car arrive, happen at 140
# Event: car leave, happen at 141
# Event: car check, happen at 141
# Event: car arrive, happen at 141
# Event: car leave, happen at 142
# Event: car check, happen at 142
# Event: car arrive, happen at 143
# Event: car leave, happen at 144
# Event: car check, happen at 144
# Event: car arrive, happen at 145
# Event: car leave, happen at 146
# Event: car check, happen at 146
# Event: car leave, happen at 147
# Event: car check, happen at 147
# Event: car arrive, happen at 147
# Event: car leave, happen at 148
# Event: car check, happen at 148
# Event: car arrive, happen at 149
# Event: car leave, happen at 150
# Event: car check, happen at 150
# Event: car arrive, happen at 150
# Event: car arrive, happen at 151
# Event: car leave, happen at 152
# Event: car check, happen at 152
# Event: car arrive, happen at 152
# Event: car leave, happen at 153
# Event: car check, happen at 153
# Event: car arrive, happen at 154
# Event: car leave, happen at 154
# Event: car check, happen at 154
# Event: car arrive, happen at 156
# Event: car leave, happen at 157
# Event: car check, happen at 157
# Event: car arrive, happen at 157
# Event: car leave, happen at 158
# Event: car check, happen at 158
# Event: car arrive, happen at 158
# Event: car leave, happen at 159
# Event: car check, happen at 159
# Event: car arrive, happen at 160
# Event: car arrive, happen at 161
# Event: car leave, happen at 162
# Event: car check, happen at 162
# Event: car arrive, happen at 162
# Event: car leave, happen at 163
# Event: car check, happen at 163
# Event: car arrive, happen at 163
# Event: car leave, happen at 163
# Event: car check, happen at 163
# Event: car arrive, happen at 164
# Event: car arrive, happen at 166
# Event: car leave, happen at 167
# Event: car check, happen at 167
# Event: car leave, happen at 167
# Event: car check, happen at 167
# Event: car arrive, happen at 167
# Event: car leave, happen at 167
# Event: car check, happen at 167
# Event: car arrive, happen at 168
# Event: car arrive, happen at 169
# Event: car arrive, happen at 170
# Event: car leave, happen at 171
# Event: car check, happen at 171
# Event: car arrive, happen at 171
# Event: car leave, happen at 172
# Event: car check, happen at 172
# Event: car arrive, happen at 172
# Event: car leave, happen at 172
# Event: car check, happen at 172
# Event: car arrive, happen at 174
# Event: car leave, happen at 175
# Event: car check, happen at 175
# Event: car leave, happen at 176
# Event: car check, happen at 176
# Event: car arrive, happen at 176
# Event: car leave, happen at 176
# Event: car check, happen at 176
# Event: car arrive, happen at 178
# Event: car leave, happen at 179
# Event: car check, happen at 179
# Event: car arrive, happen at 179
# Event: car leave, happen at 180
# Event: car check, happen at 180
# Event: car arrive, happen at 180
# Event: car leave, happen at 181
# Event: car check, happen at 181
# Event: car arrive, happen at 182
# Event: car leave, happen at 183
# Event: car check, happen at 183
# Event: car arrive, happen at 183
# Event: car leave, happen at 184
# Event: car check, happen at 184
# Event: car leave, happen at 185
# Event: car check, happen at 185
# Event: car arrive, happen at 185
# Event: car arrive, happen at 186
# Event: car arrive, happen at 187
# Event: car leave, happen at 188
# Event: car check, happen at 188
# Event: car leave, happen at 188
# Event: car check, happen at 188
# Event: car leave, happen at 189
# Event: car check, happen at 189
# Event: car arrive, happen at 189
# Event: car arrive, happen at 191
# Event: car leave, happen at 193
# Event: car check, happen at 193
# Event: car leave, happen at 193
# Event: car check, happen at 193
# Event: car arrive, happen at 193
# Event: car leave, happen at 193
# Event: car check, happen at 193
# Event: car arrive, happen at 195
# Event: car leave, happen at 197
# Event: car check, happen at 197
# Event: car leave, happen at 197
# Event: car check, happen at 197
# Event: car arrive, happen at 197
# Event: car leave, happen at 197
# Event: car check, happen at 197
# Event: car arrive, happen at 199
# Event: car arrive, happen at 200
# Event: car leave, happen at 201
# Event: car check, happen at 201
# Event: car leave, happen at 201
# Event: car check, happen at 201
# Event: car arrive, happen at 202
# Event: car leave, happen at 202
# Event: car check, happen at 202
# Event: car arrive, happen at 204
# Event: car leave, happen at 205
# Event: car check, happen at 205
# Event: car leave, happen at 206
# Event: car check, happen at 206
# Event: car arrive, happen at 206
# Event: car leave, happen at 206
# Event: car check, happen at 206
# Event: car arrive, happen at 208
# Event: car leave, happen at 209
# Event: car check, happen at 209
# Event: car arrive, happen at 209
# Event: car leave, happen at 210
# Event: car check, happen at 210
# Event: car arrive, happen at 210
# Event: car leave, happen at 211
# Event: car check, happen at 211
# Event: car arrive, happen at 211
# Event: car arrive, happen at 212
# Event: car leave, happen at 214
# Event: car check, happen at 214
# Event: car arrive, happen at 214
# Event: car leave, happen at 215
# Event: car check, happen at 215
# Event: car leave, happen at 215
# Event: car check, happen at 215
# Event: car arrive, happen at 216
# Event: car leave, happen at 218
# Event: car check, happen at 218
# Event: car arrive, happen at 218
# Event: car leave, happen at 219
# Event: car check, happen at 219
# Event: car arrive, happen at 219
# Event: car leave, happen at 220
# Event: car check, happen at 220
# Event: car arrive, happen at 221
# Event: car leave, happen at 223
# Event: car check, happen at 223
# Event: car arrive, happen at 223
# Event: car leave, happen at 223
# Event: car check, happen at 223
# Event: car leave, happen at 224
# Event: car check, happen at 224
# Event: car arrive, happen at 225
# Event: car leave, happen at 227
# Event: car check, happen at 227
# Event: car arrive, happen at 227
# Event: car leave, happen at 227
# Event: car check, happen at 227
# Event: car leave, happen at 228
# Event: car check, happen at 228
# Event: car arrive, happen at 228
# Event: car arrive, happen at 229
# Event: car arrive, happen at 230
# Event: car leave, happen at 231
# Event: car check, happen at 231
# Event: car arrive, happen at 231
# Event: car leave, happen at 231
# Event: car check, happen at 231
# Event: car leave, happen at 232
# Event: car check, happen at 232
# Event: car arrive, happen at 233
# Event: car arrive, happen at 235
# Event: car leave, happen at 236
# Event: car check, happen at 236
# Event: car leave, happen at 236
# Event: car check, happen at 236
# Event: car leave, happen at 237
# Event: car check, happen at 237
# Event: car arrive, happen at 237
# Event: car arrive, happen at 239
# Event: car leave, happen at 240
# Event: car check, happen at 240
# Event: car leave, happen at 241
# Event: car check, happen at 241
# Event: car arrive, happen at 241
# Event: car leave, happen at 241
# Event: car check, happen at 241
# Event: car arrive, happen at 242
# Event: car arrive, happen at 244
# Event: car leave, happen at 245
# Event: car check, happen at 245
# Event: car arrive, happen at 245
# Event: car leave, happen at 246
# Event: car check, happen at 246
# Event: car leave, happen at 246
# Event: car check, happen at 246
# Event: car arrive, happen at 247
# Event: car arrive, happen at 248
# Event: car leave, happen at 249
# Event: car check, happen at 249
# Event: car leave, happen at 250
# Event: car check, happen at 250
# Event: car arrive, happen at 250
# Event: car leave, happen at 250
# Event: car check, happen at 250
# Event: car arrive, happen at 252
# Event: car leave, happen at 253
# Event: car check, happen at 253
# Event: car arrive, happen at 253
# Event: car leave, happen at 254
# Event: car check, happen at 254
# Event: car arrive, happen at 254
# Event: car leave, happen at 254
# Event: car check, happen at 254
# Event: car arrive, happen at 256
# Event: car leave, happen at 258
# Event: car check, happen at 258
# Event: car leave, happen at 258
# Event: car arrive, happen at 258
# Event: car check, happen at 258
# Event: car leave, happen at 259
# Event: car arrive, happen at 259
# Event: car check, happen at 259
# Event: car arrive, happen at 260
# Event: car leave, happen at 262
# Event: car check, happen at 262
# Event: car arrive, happen at 262
# Event: car leave, happen at 263
# Event: car check, happen at 263
# Event: car arrive, happen at 263
# Event: car leave, happen at 264
# Event: car check, happen at 264
# Event: car arrive, happen at 265
# Event: car arrive, happen at 266
# Event: car leave, happen at 267
# Event: car check, happen at 267
# Event: car leave, happen at 267
# Event: car check, happen at 267
# Event: car arrive, happen at 268
# Event: car leave, happen at 269
# Event: car check, happen at 269
# Event: car arrive, happen at 270
# Event: car leave, happen at 271
# Event: car check, happen at 271
# Event: car arrive, happen at 271
# Event: car leave, happen at 271
# Event: car check, happen at 271
# Event: car arrive, happen at 273
# Event: car leave, happen at 274
# Event: car check, happen at 274
# Event: car arrive, happen at 274
# Event: car leave, happen at 275
# Event: car check, happen at 275
# Event: car arrive, happen at 275
# Event: car leave, happen at 275
# Event: car check, happen at 275
# Event: car arrive, happen at 277
# Event: car leave, happen at 278
# Event: car check, happen at 278
# Event: car arrive, happen at 279
# Event: car leave, happen at 280
# Event: car check, happen at 280
# Event: car arrive, happen at 280
# Event: car leave, happen at 280
# Event: car check, happen at 280
# Event: car arrive, happen at 281
# Event: car leave, happen at 282
# Event: car check, happen at 282
# Event: car arrive, happen at 283
# Event: car leave, happen at 284
# Event: car check, happen at 284
# Event: car arrive, happen at 284
# Event: car leave, happen at 284
# Event: car check, happen at 284
# Event: car leave, happen at 286
# Event: car arrive, happen at 286
# Event: car check, happen at 286
# Event: car arrive, happen at 287
# Event: car leave, happen at 288
# Event: car check, happen at 288
# Event: car leave, happen at 289
# Event: car arrive, happen at 289
# Event: car check, happen at 289
# Event: car arrive, happen at 290
# Event: car leave, happen at 291
# Event: car check, happen at 291
# Event: car arrive, happen at 291
# Event: car arrive, happen at 292
# Event: car leave, happen at 293
# Event: car check, happen at 293
# Event: car arrive, happen at 294
# Event: car leave, happen at 294
# Event: car check, happen at 294
# Event: car leave, happen at 296
# Event: car check, happen at 296
# Event: car arrive, happen at 296
# Event: car leave, happen at 297
# Event: car check, happen at 297
# Event: car arrive, happen at 297
# Event: car leave, happen at 298
# Event: car check, happen at 298
# Event: car arrive, happen at 299
# Event: car leave, happen at 300
# Event: car check, happen at 300
# Event: car leave, happen at 301
# Event: car arrive, happen at 301
# Event: car check, happen at 301
# Event: car arrive, happen at 302
# Event: car leave, happen at 303
# Event: car check, happen at 303
# Event: car arrive, happen at 303
# Event: car leave, happen at 305
# Event: car check, happen at 305
# Event: car arrive, happen at 305
# Event: car leave, happen at 305
# Event: car check, happen at 305
# Event: car arrive, happen at 306
# Event: car leave, happen at 308
# Event: car check, happen at 308
# Event: car arrive, happen at 308
# Event: car leave, happen at 309
# Event: car check, happen at 309
